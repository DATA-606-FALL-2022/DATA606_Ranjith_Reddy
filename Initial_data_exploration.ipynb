# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
aisles=pd.read_csv("data/aisles.csv")
aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
aisles.shape
# Out:
# (134, 2)

# %%
aisles.head(10)
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
# 5         6                       other
# 6         7               packaged meat
# 7         8             bakery desserts
# 8         9                 pasta sauce
# 9        10            kitchen supplies

# %%
departments=pd.read_csv("data/departments.csv")
departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
departments.shape
# Out:
# (21, 2)

# %%
departments.head(10)
# Out:
#    department_id       department
# 0              1           frozen
# 1              2            other
# 2              3           bakery
# 3              4          produce
# 4              5          alcohol
# 5              6    international
# 6              7        beverages
# 7              8             pets
# 8              9  dry goods pasta
# 9             10             bulk

# %%
orders=pd.read_csv("data/orders.csv")
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
orders.shape
# Out:
# (3421083, 7)

# %%
orders.head(10)
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
# 5   3367565        1    prior             6          2                  7
# 6    550135        1    prior             7          1                  9
# 7   3108588        1    prior             8          1                 14
# 8   2295261        1    prior             9          1                 16
# 9   2550362        1    prior            10          4                  8
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0
# 5                    19.0
# 6                    20.0
# 7                    14.0
# 8                     0.0
# 9                    30.0

# %%
products=pd.read_csv("data/products.csv")
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49688 entries, 0 to 49687
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49688 non-null  int64
#  1   product_name   49688 non-null  object
#  2   aisle_id       49688 non-null  int64
#  3   department_id  49688 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
products.shape
# Out:
# (49688, 4)

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
order_products=pd.read_csv("data/order_products__prior.csv")
order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
order_products.shape
# Out:
# (32434489, 4)

# %%
order_products.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df=pd.DataFrame()

# %%
df=pd.merge(aisles, products, how="inner", on="aisle_id")
df.head()
# Out:
#    aisle_id                  aisle  product_id  \
# 0         1  prepared soups salads         209
# 1         1  prepared soups salads         554
# 2         1  prepared soups salads         886
# 3         1  prepared soups salads        1600
# 4         1  prepared soups salads        2539
#
#                                         product_name  department_id
# 0                                Italian Pasta Salad             20
# 1                                       Turkey Chili             20
# 2  Whole Grain Salad with Roasted Pecans & Mango ...             20
# 3                           Mediterranean Orzo Salad             20
# 4                              Original Potato Salad             20

# %%
df=pd.merge(df, departments, how="inner", on="department_id")
df.head()
# Out:
#    aisle_id                  aisle  product_id  \
# 0         1  prepared soups salads         209
# 1         1  prepared soups salads         554
# 2         1  prepared soups salads         886
# 3         1  prepared soups salads        1600
# 4         1  prepared soups salads        2539
#
#                                         product_name  department_id department
# 0                                Italian Pasta Salad             20       deli
# 1                                       Turkey Chili             20       deli
# 2  Whole Grain Salad with Roasted Pecans & Mango ...             20       deli
# 3                           Mediterranean Orzo Salad             20       deli
# 4                              Original Potato Salad             20       deli

# %%
df=pd.merge(df, order_products,  how="inner", on="product_id")
df.head()
# Out:
#    aisle_id                  aisle  product_id         product_name  \
# 0         1  prepared soups salads         209  Italian Pasta Salad
# 1         1  prepared soups salads         209  Italian Pasta Salad
# 2         1  prepared soups salads         209  Italian Pasta Salad
# 3         1  prepared soups salads         209  Italian Pasta Salad
# 4         1  prepared soups salads         209  Italian Pasta Salad
#
#    department_id department  order_id  add_to_cart_order  reordered
# 0             20       deli     94246                  5          0
# 1             20       deli    192465                  2          1
# 2             20       deli    195206                 18          1
# 3             20       deli    227717                  1          1
# 4             20       deli    260072                 13          0

# %%
df=pd.merge(df, orders,  how="inner", on="order_id")
df.head()
# Out:
#    aisle_id                  aisle  product_id  \
# 0         1  prepared soups salads         209
# 1         1  prepared soups salads       22853
# 2        13         prepared meals       10089
# 3        13         prepared meals       19687
# 4        61          cookies cakes       46373
#
#                         product_name  department_id department  order_id  \
# 0                Italian Pasta Salad             20       deli     94246
# 1                  Pesto Pasta Salad             20       deli     94246
# 2                             Dolmas             20       deli     94246
# 3  Butternut Squash With Cranberries             20       deli     94246
# 4                   Donuts, Powdered             19     snacks     94246
#
#    add_to_cart_order  reordered  user_id eval_set  order_number  order_dow  \
# 0                  5          0   114082    prior            26          0
# 1                  4          0   114082    prior            26          0
# 2                 25          0   114082    prior            26          0
# 3                  6          0   114082    prior            26          0
# 4                 21          0   114082    prior            26          0
#
#    order_hour_of_day  days_since_prior_order
# 0                 20                     1.0
# 1                 20                     1.0
# 2                 20                     1.0
# 3                 20                     1.0
# 4                 20                     1.0

# %%
groceries=df

# %%
groceries.head(10)
# Out:
#    aisle_id                       aisle  product_id  \
# 0         1       prepared soups salads         209
# 1         1       prepared soups salads       22853
# 2        13              prepared meals       10089
# 3        13              prepared meals       19687
# 4        61               cookies cakes       46373
# 5         4               instant foods       12087
# 6         4               instant foods       47570
# 7        63     grains rice dried goods       26313
# 8        51      preserved dips spreads       19415
# 9       105  doughs gelatins bake mixes       47437
#
#                                product_name  department_id       department  \
# 0                       Italian Pasta Salad             20             deli
# 1                         Pesto Pasta Salad             20             deli
# 2                                    Dolmas             20             deli
# 3         Butternut Squash With Cranberries             20             deli
# 4                          Donuts, Powdered             19           snacks
# 5          Chicken Flavor Ramen Noodle Soup              9  dry goods pasta
# 6  Original Flavor Macaroni & Cheese Dinner              9  dry goods pasta
# 7                          Pad Thai Noodles              9  dry goods pasta
# 8    Roasted Tomato Salsa Serrano-Tomatillo             13           pantry
# 9             California Apricot Scones Mix             13           pantry
#
#    order_id  add_to_cart_order  reordered  user_id eval_set  order_number  \
# 0     94246                  5          0   114082    prior            26
# 1     94246                  4          0   114082    prior            26
# 2     94246                 25          0   114082    prior            26
# 3     94246                  6          0   114082    prior            26
# 4     94246                 21          0   114082    prior            26
# 5     94246                 15          0   114082    prior            26
# 6     94246                 14          1   114082    prior            26
# 7     94246                  2          1   114082    prior            26
# 8     94246                 26          0   114082    prior            26
# 9     94246                 13          0   114082    prior            26
#
#    order_dow  order_hour_of_day  days_since_prior_order
# 0          0                 20                     1.0
# 1          0                 20                     1.0
# 2          0                 20                     1.0
# 3          0                 20                     1.0
# 4          0                 20                     1.0
# 5          0                 20                     1.0
# 6          0                 20                     1.0
# 7          0                 20                     1.0
# 8          0                 20                     1.0
# 9          0                 20                     1.0

# %%
groceries.columns
# Out:
# Index(['aisle_id', 'aisle', 'product_id', 'product_name', 'department_id',
#        'department', 'order_id', 'add_to_cart_order', 'reordered', 'user_id',
#        'eval_set', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='object')

# %%
groceries.shape
# Out:
# (32434489, 15)

# %%
groceries.describe()
# Out:
#            aisle_id    product_id  department_id      order_id  \
# count  3.243449e+07  3.243449e+07   3.243449e+07  3.243449e+07
# mean   7.121430e+01  2.557634e+04   9.921906e+00  1.710749e+06
# std    3.820302e+01  1.409669e+04   6.281156e+00  9.873007e+05
# min    1.000000e+00  1.000000e+00   1.000000e+00  2.000000e+00
# 25%    3.100000e+01  1.353000e+04   4.000000e+00  8.559430e+05
# 50%    8.300000e+01  2.525600e+04   9.000000e+00  1.711048e+06
# 75%    1.070000e+02  3.793500e+04   1.600000e+01  2.565514e+06
# max    1.340000e+02  4.968800e+04   2.100000e+01  3.421083e+06
#
#        add_to_cart_order     reordered       user_id  order_number  \
# count       3.243449e+07  3.243449e+07  3.243449e+07  3.243449e+07
# mean        8.351076e+00  5.896975e-01  1.029372e+05  1.714205e+01
# std         7.126671e+00  4.918886e-01  5.946648e+04  1.753504e+01
# min         1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# 25%         3.000000e+00  0.000000e+00  5.142100e+04  5.000000e+00
# 50%         6.000000e+00  1.000000e+00  1.026110e+05  1.100000e+01
# 75%         1.100000e+01  1.000000e+00  1.543910e+05  2.400000e+01
# max         1.450000e+02  1.000000e+00  2.062090e+05  9.900000e+01
#
#           order_dow  order_hour_of_day  days_since_prior_order
# count  3.243449e+07       3.243449e+07            3.035642e+07
# mean   2.738818e+00       1.342498e+01            1.110407e+01
# std    2.090049e+00       4.246365e+00            8.778914e+00
# min    0.000000e+00       0.000000e+00            0.000000e+00
# 25%    1.000000e+00       1.000000e+01            5.000000e+00
# 50%    3.000000e+00       1.300000e+01            8.000000e+00
# 75%    5.000000e+00       1.600000e+01            1.500000e+01
# max    6.000000e+00       2.300000e+01            3.000000e+01

# %%
groceries.isna().sum()
# Out:
# aisle_id                        0
# aisle                           0
# product_id                      0
# product_name                    0
# department_id                   0
# department                      0
# order_id                        0
# add_to_cart_order               0
# reordered                       0
# user_id                         0
# eval_set                        0
# order_number                    0
# order_dow                       0
# order_hour_of_day               0
# days_since_prior_order    2078068
# dtype: int64

# %%
groceries.dtypes
# Out:
# aisle_id                    int64
# aisle                      object
# product_id                  int64
# product_name               object
# department_id               int64
# department                 object
# order_id                    int64
# add_to_cart_order           int64
# reordered                   int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
all_orders = groceries[['user_id','order_id','product_id','product_name','aisle_id','aisle','department_id','department','add_to_cart_order']]
all_orders.head()
# Out:
#    user_id  order_id  product_id                       product_name  aisle_id  \
# 0   114082     94246         209                Italian Pasta Salad         1
# 1   114082     94246       22853                  Pesto Pasta Salad         1
# 2   114082     94246       10089                             Dolmas        13
# 3   114082     94246       19687  Butternut Squash With Cranberries        13
# 4   114082     94246       46373                   Donuts, Powdered        61
#
#                    aisle  department_id department  add_to_cart_order
# 0  prepared soups salads             20       deli                  5
# 1  prepared soups salads             20       deli                  4
# 2         prepared meals             20       deli                 25
# 3         prepared meals             20       deli                  6
# 4          cookies cakes             19     snacks                 21

# %%
all_orders[all_orders['user_id']==114082]
# Out:
#           user_id  order_id  product_id  \
# 0          114082     94246         209
# 1          114082     94246       22853
# 2          114082     94246       10089
# 3          114082     94246       19687
# 4          114082     94246       46373
# ...           ...       ...         ...
# 25686864   114082   2492129       18567
# 25686865   114082   2492129       34124
# 27650721   114082    499057       38312
# 27650722   114082    499057        8386
# 27650723   114082    499057       35055
#
#                                                product_name  aisle_id  \
# 0                                       Italian Pasta Salad         1
# 1                                         Pesto Pasta Salad         1
# 2                                                    Dolmas        13
# 3                         Butternut Squash With Cranberries        13
# 4                                          Donuts, Powdered        61
# ...                                                     ...       ...
# 25686864                     Low Fat No Chicken Noodle Soup        69
# 25686865              Organic Low Fat Vegetable Barley Soup        69
# 27650721                      Almond Milk Strawberry Yogurt       120
# 27650722  4X Ultra Concentrated Natural Laundry Detergen...        75
# 27650723                   Just Cranberry Unsweetened Juice        98
#
#                           aisle  department_id    department  \
# 0         prepared soups salads             20          deli
# 1         prepared soups salads             20          deli
# 2                prepared meals             20          deli
# 3                prepared meals             20          deli
# 4                 cookies cakes             19        snacks
# ...                         ...            ...           ...
# 25686864    soup broth bouillon             15  canned goods
# 25686865    soup broth bouillon             15  canned goods
# 27650721                 yogurt             16    dairy eggs
# 27650722                laundry             17     household
# 27650723          juice nectars              7     beverages
#
#           add_to_cart_order
# 0                         5
# 1                         4
# 2                        25
# 3                         6
# 4                        21
# ...                     ...
# 25686864                  9
# 25686865                  8
# 27650721                  3
# 27650722                  1
# 27650723                  2
#
# [455 rows x 9 columns]

# %%
print(str(len(all_orders.user_id.unique())) +' customers')
print(str(len(all_orders.order_id.unique())) +' order')
print(str(len(all_orders.aisle_id.unique())) +' aisles')
print(str(len(all_orders.product_id.unique())) +' products')
# Out:
# 206209 customers
# 3214874 order
# 134 aisles
# 49677 products

# %%
all_orders.groupby('user_id')['order_id'].nunique().describe()
# Out:
# count    206209.000000
# mean         15.590367
# std          16.654774
# min           3.000000
# 25%           5.000000
# 50%           9.000000
# 75%          19.000000
# max          99.000000
# Name: order_id, dtype: float64

# %%
def visualize(x,y,z):
    x = sns.barplot(data = groceries.groupby(x)[y].sum().sort_values(ascending = False).reset_index()[0:30], x = x, y = y)
    x.set_xticklabels(x.get_xticklabels(), rotation = 90)
    x.set(xlabel = z, ylabel = 'Units Ordered')

# %%
visualize('department','add_to_cart_order','Department')

# %%
visualize('aisle','add_to_cart_order','Aisle')

# %%
visualize('product_name','add_to_cart_order','Product Name')

# %%
groceries.columns

# %% [markdown]
# ### Which day of the week most orders are placed?
#
# Based on the below graph, Sunday seems to be the day most orders are placed. This is expected as people stock up for the week. Monday is the next day with most orders.

# %%
visualize('order_dow','add_to_cart_order','order_dow')

# %% [markdown]
# ### Which hour of the day most orders are placed?
#
# As shown below, most of the orders are placed in the hours from 10 am - 4 pm. It is expected that more orders are placed during the day.

# %%
visualize('order_hour_of_day','add_to_cart_order','order_hour_of_day')

# %% [markdown]
# ### How often do people place grocery orders?
#
# This can be inferred from the days since prior order information. It is seen that moslty people have ordered prior to 7 days and 30 days. This is also expected as people generally stock up weekly or monthly.

# %%
visualize('days_since_prior_order','add_to_cart_order','days_since_prior_order')

# %% [markdown]
# ### Which aisles are most busy?

# %%
# Using groupBy to group the rows based on aisle
groceries.groupby("aisle")['aisle_id'].count().sort_values(ascending=False)

# %% [markdown]
# ### Which aisles are most busy in a given hour of the day?
#
# Understanding which aisle is most busy in the different hours of the day can help the company stock up and place more staff at the warehouses and for delivery. It is seen that 'fresh fruits and veggies' are the ordered throughout the day and they need to be stocked up regularly.

# %%
groceries.groupby(["aisle", "order_hour_of_day"])['aisle_id'].count().sort_values(ascending=False)

# %% [markdown]
# ### Which departments are most busy in a given hour of the day?

# %%
# Using groupBy for both department and order_hour_of_day 
groceries.groupby(["department", "order_hour_of_day"])['department_id'].count().sort_values(ascending=False)

# %% [markdown]
# ### Which products have most demand?
#
# Based on this, we can understand the consumption trends and stock up products accordingly to keep the business running efficiently. Products from the produce department are the most consumed. Within the produce department, bananas, spinach and avacados are among the top products that are consumed.

# %%
groceries.groupby("product_name")['product_id'].count().sort_values(ascending=False)

# %% [markdown]
# ### Which products were added first to the cart majority times?
#
# The products from the fresh produce department are most ordered and also are the ones that are added to the cart initially.

# %%
add2cart_1=groceries[groceries['add_to_cart_order']==1]
add2cart_1.groupby("product_name")['product_id'].count().sort_values(ascending=False)

# %%
add2cart_2=groceries[groceries['add_to_cart_order']==2]
add2cart_2.groupby("product_name")['product_id'].count().sort_values(ascending=False)

# %%
add2cart_3=groceries[groceries['add_to_cart_order']==3]
add2cart_3.groupby("product_name")['product_id'].count().sort_values(ascending=False)
